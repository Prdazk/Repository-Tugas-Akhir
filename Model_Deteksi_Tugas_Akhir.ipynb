# %% [markdown]
# <a href="https://colab.research.google.com/github/Prdazk/Repository-Tugas-Akhir/blob/main/Model_Deteksi_Tugas_Akhir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.listdir("/content/drive/MyDrive/")
# Out:
# ['Repository Tugas Akhir',
#  '1754717173859.jpg',
#  'KEAMANAN JARINGAN',
#  'what_happens_to_your_brain_when_you_study_advanced_math.pdf',
#  'what_happens_to_your_brain_when_you_study_advanced_math.gdoc',
#  'Untitled0.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'PROYEK TI',
#  'datascience.ipynb',
#  'Tugas.ipynb',
#  'Untitled4.ipynb',
#  'Colab Notebooks',
#  'Untitled (19)',
#  'Untitled (18)',
#  'Untitled (17)',
#  'Untitled (16)',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Laduni_Prada.explore_data_(2).ipynb',
#  'Untitled (15)',
#  'Untitled (14)',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Untitled (13)',
#  'Lecture 03 -- ML Mechanics - Techniques.pdf',
#  'Pertemuan3.ipynb',
#  'Lecture 03 -- ML Mechanics - Techniques.gdoc',
#  'UseCase.drawio',
#  'Untitled10.ipynb',
#  'Formulir tanpa judul (1).gform',
#  'Informasi Kontak.gform',
#  'Penilaian.gform',
#  'Formulir tanpa judul.gform',
# ...

# %%
import os

path = "/content/drive/MyDrive/Repository Tugas Akhir/Dataset/Dataset Model TA"
os.listdir(path)
# Out:
# ['motor.zip', 'bus.zip', 'mobil.zip', 'truk.zip']

# %%
import zipfile
import os

base_path = "/content/drive/MyDrive/Repository Tugas Akhir/Dataset/Dataset Model TA"
extract_path = "/content/DatasetTA"

os.makedirs(extract_path, exist_ok=True)

for file in os.listdir(base_path):
    if file.endswith(".zip"):
        zip_path = os.path.join(base_path, file)
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_path)

print("Selesai extract")
# Out:
# Selesai extract

# %%
os.listdir("/content/DatasetTA")
# Out:
# ['README.roboflow.txt',
#  'valid',
#  'README.dataset.txt',
#  'data.yaml',
#  'test',
#  'train']
