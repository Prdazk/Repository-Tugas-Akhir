# %% [markdown]
# <a href="https://colab.research.google.com/github/Prdazk/Repository-Tugas-Akhir/blob/main/Training_model_TA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive

# %%
# !ls "/content/drive/MyDrive/Repository Tugas Akhir/Dataset Training"
# Out:
# 'Salinan dataset_helm.zip'
# 'Salinan Motorcycle Riders in Traffic.v1i.yolov8.zip'
# 'Salinan No Helmet Detection.v1-v1.yolov8.zip'

# %%
# !mkdir /content/dataset_helm

# %%
# !cp "/content/drive/MyDrive/Repository Tugas Akhir/Dataset Training/Salinan dataset_helm.zip" /content/dataset_helm/
# !cp "/content/drive/MyDrive/Repository Tugas Akhir/Dataset Training/Salinan Motorcycle Riders in Traffic.v1i.yolov8.zip" /content/dataset_helm/
# !cp "/content/drive/MyDrive/Repository Tugas Akhir/Dataset Training/Salinan No Helmet Detection.v1-v1.yolov8.zip" /content/dataset_helm/

# %%
import zipfile, os

zip_path = "/content/dataset_helm"

for file in os.listdir(zip_path):
    if file.endswith(".zip"):
        filepath = os.path.join(zip_path, file)
        print("Extracting:", file)
        with zipfile.ZipFile(filepath, 'r') as zip_ref:
            zip_ref.extractall(zip_path)
# Out:
# Extracting: Salinan Motorcycle Riders in Traffic.v1i.yolov8.zip
# Extracting: Salinan No Helmet Detection.v1-v1.yolov8.zip
# Extracting: Salinan dataset_helm.zip

# %%
# !ls /content/dataset_helm
# Out:
#  data.yaml
#  README.dataset.txt
#  README.roboflow.txt
# 'Salinan dataset_helm.zip'
# 'Salinan Motorcycle Riders in Traffic.v1i.yolov8.zip'
# 'Salinan No Helmet Detection.v1-v1.yolov8.zip'
#  test
#  train
#  valid

# %%
# !ls /content/dataset_helm/train
# Out:
# images	labels

# %%
yaml_content = """
train: /content/dataset_helm/train/images
val: /content/dataset_helm/valid/images

nc: 2
names: ["helmet", "no_helmet"]
"""

with open('/content/dataset_helm/data.yaml', 'w') as f:
    f.write(yaml_content)

print("data.yaml updated.")
# Out:
# data.yaml updated.

# %%
# !pip install ultralytics

# %%
# !find /content -maxdepth 5 -type f -name "*.pt"
# Out:
# /content/runs/detect/train2/weights/last.pt
# /content/runs/detect/train2/weights/best.pt

# %%
# !ls -lha
# Out:
# total 6.3M
# drwxr-xr-x 1 root root 4.0K Jan 19 14:45 .
# drwxr-xr-x 1 root root 4.0K Jan 19 14:33 ..
# drwxr-xr-x 4 root root 4.0K Dec 11 14:34 .config
# drwxr-xr-x 5 root root 4.0K Jan 19 14:44 dataset_helm
# drwx------ 5 root root 4.0K Jan 19 14:44 drive
# drwxr-xr-x 3 root root 4.0K Jan 19 14:45 runs
# drwxr-xr-x 1 root root 4.0K Dec 11 14:34 sample_data
# -rw-r--r-- 1 root root 6.3M Jan 19 14:45 yolov8n.pt

# %%
# !cp /content/runs/detect/train2/weights/best.pt /content/konfigurasi.pt

# %%
# !ls -lha /content
# Out:
# total 18M
# drwxr-xr-x 1 root root 4.0K Jan 19 15:42 .
# drwxr-xr-x 1 root root 4.0K Jan 19 14:33 ..
# drwxr-xr-x 4 root root 4.0K Dec 11 14:34 .config
# drwxr-xr-x 5 root root 4.0K Jan 19 14:44 dataset_helm
# drwx------ 5 root root 4.0K Jan 19 14:44 drive
# drwxr-xr-x 2 root root 4.0K Jan 19 15:38 .ipynb_checkpoints
# -rw-r--r-- 1 root root  18M Jan 19 15:42 konfigurasi.pt
# drwxr-xr-x 3 root root 4.0K Jan 19 14:45 runs
# drwxr-xr-x 1 root root 4.0K Dec 11 14:34 sample_data

# %%
from ultralytics import YOLO

model = YOLO('/content/konfigurasi.pt')

model.train(
    data='/content/dataset_helm/data.yaml',
    epochs=3,
    imgsz=640,
    batch=16,
    patience=30,
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
